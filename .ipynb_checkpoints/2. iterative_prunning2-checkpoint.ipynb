# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import math

# import import_ipynb
from graph_functions import *
from iterative_pruning_func import *

# %%
G, n, _ = generate_graphs(26)[1]     # prism
fully_infect(G)

# display_graph_stage(G, prism=True)

# 1. stage
print("initial removal")
minimise_infection(G, 0)
pc = calc_graph_values(G)
display_graph_stage(G, prism=True, figsize=(8, 4))

# print(pc)
calc_values(G)

def get_candidate(G):
    for i in G.nodes:
        e = G.nodes[i]
        # print(i, e)
        if e.get("infected"):
            adj = G.adj[i]
            c = 0
            for x in adj:
                z =  G.nodes[x]
                if G.nodes[x].get("infected_n") - 1 >= 2:
                    c += 1

            if c >= 3:
                return i

for _ in range(5):
    i = get_candidate(G)
    e = pc[i]
    print("removal of element ", i, " -> ", G.nodes[i])
    G.nodes[i]["infected"] = False
    pc = calc_graph_values(G)
    
    H, infected_nodes, healthy_nodes = fully_endemic(G)
    print("Graph healhy nodes ", healthy_nodes)
    
    display_graph_stage(G, prism=True)
# Out:
# number of graphs for n=26 : 2
# initial removal
# removal of element  2  ->  {'infected': 1, 'infection_influence': 3, 'infected_n': 0, 'healthy_n': 3}
# Graph healhy nodes  []
# removal of element  5  ->  {'infected': 1, 'infection_influence': 3, 'infected_n': 0, 'healthy_n': 3}
# Graph healhy nodes  []
# removal of element  6  ->  {'infected': 1, 'infection_influence': 3, 'infected_n': 0, 'healthy_n': 3}
# Graph healhy nodes  []
# removal of element  9  ->  {'infected': 1, 'infection_influence': 3, 'infected_n': 0, 'healthy_n': 3}
# Graph healhy nodes  []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 32
#      30 for _ in range(5):
#      31     i = get_candidate(G)
# ---> 32     e = pc[i]
#      33     print("removal of element ", i, " -> ", G.nodes[i])
#      34     G.nodes[i]["infected"] = False
#
# IndexError: list index out of range
