# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import math

# import import_ipynb
from graph_functions import *
from iterative_pruning_func import *

# %%
G, n, _ = generate_graphs(26)[1]     # prism
fully_infect(G)

# display_graph_stage(G, prism=True)

# 1. stage
print("initial removal")
minimise_infection(G, 0)
pc = calc_graph_values(G)
display_graph_stage(G, prism=True)
# Out:
# number of graphs for n=26 : 2
# initial removal

# %%
G1, n, _ = generate_graphs(10)[0]     # prism

# display_graph(G1, figsize=(3, 3), pos=mobius_pos(H))
# display_graph(H, figsize=(3, 3))
# display_graph(nx.complete_graph(n), figsize=(3, 3))

H = nx.complement(G1)
Kn = nx.complete_graph(G1.number_of_nodes())
display_graphs_row(G1, H, Kn)
    
display_graph_distance_par(G1, v=2)
display_graph_distance_par(H, v=2)
display_graph_distance_par(Kn, v=2)

# display_graph_distance_par()
# Out:
# number of graphs for n=10 : 2

# %%
G1, n, _ = generate_graphs(10)[1]     # prism

H = nx.complement(G1)
Kn = nx.complete_graph(G1.number_of_nodes())
display_graphs_row(G1, H, Kn)
    
display_graph_distance_par(G1, v=2)
display_graph_distance_par(H, v=2)
display_graph_distance_par(Kn, v=2)
# Out:
# number of graphs for n=10 : 2

# %%
Kn = nx.complete_graph(6)

display_graph_distance_par(Kn)
Kn.remove_edge(0, 1)
display_graph_distance_par(Kn)

display_graph_distance_par(Kn)
Kn.remove_edge(0, 2)
Kn.remove_edge(1, 2)
display_graph_distance_par(Kn, v=0)


Kn.remove_edge(0, 4)
Kn.remove_edge(1, 4)
Kn.remove_edge(2, 4)
display_graph_distance_par(Kn, v=0)


print(list(Kn.adj[0]))
I = nx.subgraph(Kn, list(Kn.adj[0]))
display_graph_distance_par(I)
# Out:
# [3, 5]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 21
#      19 print(list(Kn.adj[0]))
#      20 I = nx.subgraph(Kn, list(Kn.adj[0]))
# ---> 21 display_graph_distance_par(I)
#
# File ~/faks/3. letnik/Teorija grafov EN (izbirni)/research paper/iterative_pruning_func.py:96, in display_graph_distance_par(G, pos, v, figsize)
#      94 display_graph2(G, labels=labels, pos=pos, ax=axes[0])
#      95 # display_graph2(G, labels=labels, pos=distance_partitions_pos(G, v=v, x_spacing=6.0, y_spacing=3.0), ax=axes[1],)
# ---> 96 display_graph2(G, labels=labels, pos=nx.bfs_layout(G, v)) #, x_spacing=6.0, y_spacing=3.0), ax=axes[1],)
#      98 plt.tight_layout()
#      99 plt.show()
#
# File ~/faks/3. letnik/Teorija grafov EN (izbirni)/research paper/.venv/lib/python3.10/site-packages/networkx/drawing/layout.py:1619, in bfs_layout(G, start, align, scale, center)
#    1616 G, center = _process_params(G, center, 2)
#    1618 # Compute layers with BFS
# -> 1619 layers = dict(enumerate(nx.bfs_layers(G, start)))
#    1621 if len(G) != sum(len(nodes) for nodes in layers.values()):
#    1622     raise nx.NetworkXError(
#    1623         "bfs_layout didn't include all nodes. Perhaps use input graph:\n"
#    1624         "        G.subgraph(nx.node_connected_component(G, start))"
#    1625     )
#
# File ~/faks/3. letnik/Teorija grafov EN (izbirni)/research paper/.venv/lib/python3.10/site-packages/networkx/algorithms/traversal/breadth_first_search.py:437, in bfs_layers(G, sources)
#     434 if sources in G:
#     435     sources = [sources]
# --> 437 current_layer = list(sources)
#     438 visited = set(sources)
#     440 for source in current_layer:
#
# TypeError: 'int' object is not iterable

# %%
G, n, _ = generate_graphs(6)[1]     # prism
H = nx.complement(G)

def tmp_dspl(X):
    J = X.copy()
    fully_infect(J)
    minimise_infection(J, 0)
    calc_values(J)
    display_graph_distance_par(J)
    # display_graph_distance_par_curved(J)



Kn = nx.complete_graph(n)
tmp_dspl(Kn)

for e in H.edges:
    Kn.remove_edge(*e)
    tmp_dspl(Kn)
# Out:
# number of graphs for n=6 : 2
